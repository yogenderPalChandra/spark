# %%
 from pyspark import SparkContext
 sc = SparkContext()
# Out:
# /home/yogender/.local/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %%
path='./1080412.html'

# %%
from pyspark.sql.session import SparkSession
import os
spark = SparkSession(sc)
#data = spark.sparkContext.wholeTextFiles(path)

# %%
cwd=os.getcwd()
html = '*html'
Lath = os.path.join(os.getcwd(), html)
Lath
# Out:
# '/.*html'

# %%
import glob
word = 'description'
cwd=os.getcwd()
html= '*html'
path = os.path.join(cwd, html)
for fpath in glob.glob(path):
    with open(fpath) as f:
        print (f)
        content = f.read()
        #print(content)
        df = spark.read.text(content)
# Out:
# <_io.TextIOWrapper name='/home/yogender/Desktop/NN/data_engineer_case_study/data/1080412.html' mode='r' encoding='UTF-8'>
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-123-4edff91ce679> in <module>
#       9         content = f.read()
#      10         #print(content)
# ---> 11         df = spark.read.text(content)
#      12
#      13
#
# ~/miniconda3/envs/pyspark/lib/python3.9/site-packages/pyspark/sql/readwriter.py in text(self, paths, wholetext, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter)
#     514         if isinstance(paths, str):
#     515             paths = [paths]
# --> 516         return self._df(self._jreader.text(self._spark._sc._jvm.PythonUtils.toSeq(paths)))
#     517
#     518     def csv(self, path, schema=None, sep=None, encoding=None, quote=None, escape=None,
#
# ...

# %%
fileDirectory = './'

# %%
spark.udf.register("text_simple_udf", text_simple_udf)
# Out:
# <function __main__.text_simple_udf(text_in)>

# %%
import glob
word = 'description'
for fpath in glob.glob("./*.html"):
    #print (fpath)
    
    #data = spark.sparkContext.wholeTextFiles(fpath)
    data = sc.textFile(fpath)
    rdd1 = data.filter(lambda x: 'class="ng-binding">Prodej' in x)
    print (rdd1.collect())
    #print (type(rdd1.collect()))
    #rdd1 = data.rdd.filter(lambda x: x.startswith('<meta name='))
    #print (data.count())
    #row = data.collect()[6]
    #print (row)
    #tow=rdd1.collect()
    #print(tow)
    #rows_split = tow.split(',')
    #print(rows_split)
    #row.flatMap(lambda word:word.split(" ")).collect()
    #print(row.split(","))
    #print (type(rows))
    #print (rows)
    #print (type(row.value))
    #row.value.flatMap(lambda word:word.split(" ")).collect()
    #rows_string = row.value.split(',')[3:5]
    #print(rows_string)
    #print (row.value)
    #print(rows.flatMap(lambda x: x.split(",")))
    #rows = data.collect()[6]
    #tst = text_simple_udf(rows)
    
    #print(rdd1.collect())
    #print(rdd1.take(10))
    #data1 = data.filter('description')
    #df = data.toDF()
    #df.show(20, False)
    #data.show(2, False)
    #data.show()
    #dataFilterRdd = data.filter(lambda x: word  in x)
    #dataFilterRdd.show()
    #data.printSchema()
    #sc.stop()
# Out:
# ['\t<title ng:bind-template="Prodej bytu 3+kk 136&nbsp;m², Masná, Praha 1 - Staré Město • Sreality.cz" class="ng-binding">Prodej bytu 3+kk 136&nbsp;m², Masná, Praha 1 - Staré Město • Sreality.cz</title>']
# ['\t<title ng:bind-template="Prodej bytu 1+kk 33&nbsp;m², Sametová, Liberec - Liberec VI-Rochlice • Sreality.cz" class="ng-binding">Prodej bytu 1+kk 33&nbsp;m², Sametová, Liberec - Liberec VI-Rochlice • Sreality.cz</title>']
# ['\t<title ng:bind-template="Prodej bytu 3+kk 132&nbsp;m² (Mezonet), Libušina, Karlovy Vary • Sreality.cz" class="ng-binding">Prodej bytu 3+kk 132&nbsp;m² (Mezonet), Libušina, Karlovy Vary • Sreality.cz</title>']
# ['\t<title ng:bind-template="Prodej bytu 2+kk 58&nbsp;m² (Mezonet), Grafická, Praha 5 - Smíchov • Sreality.cz" class="ng-binding">Prodej bytu 2+kk 58&nbsp;m² (Mezonet), Grafická, Praha 5 - Smíchov • Sreality.cz</title>']
# ...

# %%
from pyspark import SparkContext, SparkConf
#conf = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
conf = SparkConf().setMaster("local").setAppName("My App")
#sc = SparkContext.getOrCreate(SparkConf())
sc = SparkContext(conf=conf)
# Out:
# /home/yogender/.local/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %%
from pyspark.sql.types import *

# %%
from pyspark.sql import SQLContext

sqlContext = SQLContext(sc)
# Out:
# /home/yogender/.local/lib/python3.6/site-packages/pyspark/sql/context.py:79: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning

# %%
def toCSVLine(data):
    return ','.join(str(d) for d in data)

def mkfile(path):
    import os
    if not os.path.exists(path):
        os.mknod(path)
    return

# %%
import os
os.getcwd()
c= os.path.join(os.getcwd(), "/my_dir")
os.path.abspath("my_file.csv")
# Out:
# '/home/yogender/Desktop/NN/data_engineer_case_study/data/my_file.csv'

# %%
rdd = sc.parallelize([2, 3, 4])
x = rdd.map(lambda x: range(1, x)).collect()
x
# Out:
# [range(1, 2), range(1, 3), range(1, 4)]

# %%
from pyspark.sql import SQLContext, Row

# %%
import glob
for fpath in glob.glob("./*.html"):
    #print (fpath)
    products = sc.textFile(fpath)
    #print(type(products))
    #content = products.take(7)
    header = products.collect()[8]
    content = products.filter(lambda line: line==header)
    #print(type(content.collect()))
    #print(type(content))
    list_1 = content.collect()
    #print (list_1)
    #content_split_1 = content.map(lambda line: line.split(",")).collect()[0][1:]
    #content_split_1 = content.map(lambda line: line.split(",")).map(lambda line: line[1:]) \
    #.flatMap(lambda x:x) \
    
    #best one so far 
    content_split_1 = content.map(lambda line: line.split(",")).map(lambda line: line[1:]) \
    .flatMap(lambda x:x).map(lambda line: line.split('"')) \
    .map(lambda line: line[0]).map(lambda line: line.strip())
    
    
    content_split_joined = content_split_1.glom().map(lambda row: [row[0]+", "+row[1]]).flatMap(lambda x:x)
    #print(content_split_joined.collect())
    #content_split_1 = content.map(lambda line: line.split(",")).map(lambda line: line[1:]) \
    
    #.flatMap(lambda x:x).map(lambda line: line[:-3])
    
    #.map(lambda line: line.strip())
    
    
    #print(content_split_1.collect())
    #print(content_split_1.collect())
    #rows_split = content_split_1.map(lambda line: line.strip())
    #rows_split_street_city = rows_split.map(lambda p: Row(p))
    rows_split_addr = content_split_joined.map(lambda p: Row(p))
    #print(type(rows_split_addr))
    
    #print (rows_split_addr.collect())
    #print (len(rows_split_street_city.collect()))
    #print(content_split_1.collect())
    #this is how I create dataframe
    #address_row = content_split_1.map(lambda p: Row(street=p[0], city=str(p[1])))
    #print(address_row.collect())
    #print (rows_split_street_city.collect() )
    
    schemaString = "address"
    fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
    schema = StructType(fields)
    #print(len(schema))
    addressSchema = sqlContext.createDataFrame(rows_split_addr, schema)
    #addressSchema.repartition(1).write.mode('append').text("data.csv")
    addressSchema.repartition(1).write.csv(path='./data.csv', mode="append", header="true")
    #addressSchema.toPandas().to_csv('mycsv.csv')
    #print((addressSchema.count(), len(addressSchema.columns)))
    print(addressSchema.collect())
    print(type(addressSchema))
    #sc.stop()
# Out:
# [Row(address='Masná, Praha 1 - Staré Město')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Sametová, Liberec - Liberec VI-Rochlice')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Libušina, Karlovy Vary')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Grafická, Praha 5 - Smíchov')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Drnovská, Praha 6 - Ruzyně')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Mladoboleslavská, Mělník')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='V Průhoně, Mukařov - Žernovka')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Velvarská, Horoměřice')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Jakubská, Praha 1 - Staré Město')]
# <class 'pyspark.sql.dataframe.DataFrame'>
# [Row(address='Pod Lipami, Praha 3 - Žižkov')]
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
import glob
for fpath in glob.glob("./*.html"):
    print (fpath)
    products = sc.textFile(fpath)
    #print(type(products))
    #content = products.take(7)
    header = products.collect()[8]
    content = products.filter(lambda line: line==header)
    #print(type(content.collect()))
    #print(type(content))
    list_1 = content.collect()
    #print (list_1)
    #content_split_1 = content.map(lambda line: line.split(",")).collect()[0][1:]
    content_split_1 = content.map(lambda line: line.split(",")).map(lambda line: line[1:]) \
    .flatMap(lambda x:x).map(lambda line: line).map(lambda line: line.split('"')) \
    .map(lambda line: line[0])
    
    print(content_split_1.collect())
    #this is how I create dataframe
    #address_row = content_split_1.map(lambda p: Row(street=p[0], city=str(p[1])))
    #address_l = content_split_1.collect()
    #print(len(address_l))
    #print(address_row.collect())
    #print(type(content_split_1))
    #schemaString = "street city"
    #fields = [StructField(field_name, StringType(), True) for field_name in schemaString.split()]
    #print (fields)
    #addressSchema = sqlContext.createDataFrame(content_split_1)
    
    
    #df = spark.createDataFrame(data = simpleData, schema = columns)
    
    #lines = content_split_1.map(toCSVLine)
    #path_to_csv = os.getcwd()
    
    #lines.saveAsTextFile((os.path.abspath("my_file.csv")))
    #print (type(content_split_1))
    #Each first eliment of inner list
    #rdd = sc.parallelize(content_split_1.collect())
    
    #print(type(rdd))
    #print (rdd.first())
    #print (type(rdd.first()))
    
    #rdd.map(list)
    #rdd_string_parsed = rdd.map(lambda row: [str(c) for c in row])
    #rdd_string_df = rdd.toDS()
    #print(rdd_string_df.first())
    
    #rdd.map(lambda x: (x, )).toDF(['city', 'add'])
    #df = sqlContext.createDataFrame(rdd, ['street', 'city'])
    
    #df = x.toDF(["street", "city"])
    #print (df)
    #print(type(rdd))
    
    #print (hasattr(rdd, "toDF"))
    #address_toDF = content_split_1.map(lambda x: (x[0], x[1])).toDF('street','city').show()
    #content_street = content_split_1.map(lambda line: line[0])
    #print (type(content_street))
    
    
    #newRdd = rdd1.map(lambda x:(x[1],x[0])).join(rdd.map(lambda x:(x[0],(x[1],x[2]))))
    #.map(lambda line: line.split('"'))
    #content_split_1 = content_split_1.map(lambda line: line[1:])
    #content_split_1 = content.map(lambda line: (line.split(","), line[0], line[1:]))
    #print(content.collect()[0])
    #conten_list_of_list = content_split_1.collect()[0]
    #conten_list = conten_list_of_list[1:]
    
    #print(content_split_1.collect()[0])
    #print(content_split_1.collect())
    #print(content_street.collect())
    #content_split = content.map(lambda line: line.split(","))
    #print (content_split.take(0))
    #sc.stop()
# Out:
# ./1080412.html
# [' Masná', ' Praha 1 - Staré Město']
# ./695644.html
# [' Sametová', ' Liberec - Liberec VI-Rochlice']
# ./261724.html
# [' Libušina', ' Karlovy Vary']
# ./69468.html
# [' Grafická', ' Praha 5 - Smíchov']
# ./3566684.html
# [' Drnovská', ' Praha 6 - Ruzyně']
# ./531548.html
# [' Mladoboleslavská', ' Mělník']
# ./3963996.html
# [' V Průhoně', ' Mukařov - Žernovka']
# ./1650268.html
# [' Velvarská', ' Horoměřice']
# ./798556.html
# [' Jakubská', ' Praha 1 - Staré Město']
# ./3136860.html
# [' Pod Lipami', ' Praha 3 - Žižkov']

# %%
import glob
word = 'description'
for fpath in glob.glob("./*.html"):
    print (fpath)
    
    #data = spark.sparkContext.wholeTextFiles(fpath)
    data = spark.read.text(fpath)
    #rdd1 = data.rdd.filter(lambda x: "<meta name=" in x).collect()
    #rdd1 = data.rdd.filter(lambda x: x.startswith('<meta name='))
    #print (data.count())
    row = data.collect()[6]
    #print (row)
    #row.flatMap(lambda word:word.split(" "))
    #print(row.split(","))
    #print (type(rows))
    #print (rows)
    #print (type(row.value))
    #row.value.flatMap(lambda word:word.split(" ")).collect()
    rows_string = row.value.split(',')[3:5]
    rows_split = [i.split('•', 1)[0] for i in rows_string]
    print(rows_split)
    #print (row.value)
    #print(rows.flatMap(lambda x: x.split(",")))
    #rows = data.collect()[6]
    #tst = text_simple_udf(rows)
    
    #print(rdd1.collect())
    #print(rdd1.take(10))
    #data1 = data.filter('description')
    #df = data.toDF()
    #df.show(20, False)
    #data.show(2, False)
    #data.show()
    #dataFilterRdd = data.filter(lambda x: word  in x)
    #dataFilterRdd.show()
    #data.printSchema()
    sc.stop()
# Out:
# ./1080412.html
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9a444657a2e4> in <module>
#       5
#       6     #data = spark.sparkContext.wholeTextFiles(fpath)
# ----> 7     data = spark.read.text(fpath)
#       8     #rdd1 = data.rdd.filter(lambda x: "<meta name=" in x).collect()
#       9     #rdd1 = data.rdd.filter(lambda x: x.startswith('<meta name='))
#
# NameError: name 'spark' is not defined

# %%
for fname in os.listdir(fileDirectory):

    data = spark.sparkContext.wholeTextFiles(fname)
    df = data.toDF()
    df.show(1, False)
# Out:
# +-------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df = data.toDF()

# %%
df.show(20, False)
# Out:
# +-------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
df.printSchema(23)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-0bdb24d51f51> in <module>
# ----> 1 df.printSchema(23)
#
# TypeError: printSchema() takes 1 positional argument but 2 were given

# %%
sc.stop()
