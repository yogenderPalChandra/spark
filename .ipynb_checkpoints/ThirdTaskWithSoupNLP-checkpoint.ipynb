# %%
from pyspark.sql import SQLContext
from pyspark import SparkContext
from pyspark.sql.types import *

from sparknlp.base import *
from sparknlp.pretrained import PretrainedPipeline
import sparknlp
from pyspark.sql import SparkSession


from sparknlp.annotator import *
from pyspark.ml import Pipeline
#sc = SparkContext()
import sparknlp
spark = sparknlp.start()

# %%
sqlContext = SQLContext(spark)
# Out:
# /home/yogender/.local/lib/python3.6/site-packages/pyspark/sql/context.py:79: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning

# %%
rdd_l = spark.sparkContext.wholeTextFiles("./*.html")

# %%
df = rdd_l.toDF(schema=["filename", "text"]).select("text")

# %%
df.show(10)
# Out:
# +--------------------+
# |                text|
# +--------------------+
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# |<!DOCTYPE html><h...|
# +--------------------+

# %%
rules = '''

\d+&\w+;\d+&\w+;Kč* 

'''
#\S*\d+\S* Kč* 
with open('regex_rules.txt', 'w') as f:
    
    f.write(rules)

# %%
RegexMatcher().extractParamMap()
# Out:
# {Param(parent='RegexMatcher_cb41761ed270', name='lazyAnnotator', doc='Whether this AnnotatorModel acts as lazy in RecursivePipelines'): False,
#  Param(parent='RegexMatcher_cb41761ed270', name='strategy', doc='MATCH_FIRST|MATCH_ALL|MATCH_COMPLETE'): 'MATCH_ALL'}

# %%
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("assembled")

regex_matcher = RegexMatcher()\
    .setInputCols('assembled')\
    .setStrategy("MATCH_ALL")\
    .setOutputCol("regex_matches")\
    .setExternalRules(path='./regex_rules.txt', delimiter=',')

nlpPipeline = Pipeline(stages=[
    documentAssembler, 
    regex_matcher
 ])

pipelineModel = nlpPipeline.fit(df)
#df = pipelineModel.transform(df)
#empty_df = spark.createDataFrame([['']]).toDF("text")

#pipelineModel = nlpPipeline.fit(empty_df)

match_df = pipelineModel.transform(df)

match_df.select('regex_matches.result').show(truncate=50)
# Out:
# +----------------------+
# |                result|
# +----------------------+
# |[500&nbsp;000&nbsp;Kč]|
# |[200&nbsp;000&nbsp;Kč]|
# |[854&nbsp;900&nbsp;Kč]|
# |[565&nbsp;000&nbsp;Kč]|
# |[475&nbsp;000&nbsp;Kč]|
# |[500&nbsp;000&nbsp;Kč]|
# |[530&nbsp;000&nbsp;Kč]|
# |[511&nbsp;000&nbsp;Kč]|
# |[850&nbsp;000&nbsp;Kč]|
# |[490&nbsp;000&nbsp;Kč]|
# +----------------------+

# %%
rules2 = '''

\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w*............................


'''
#\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w*
#/<title>([^<]+)<\/title>/
#\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w+|\s.$\<\/
#\S*\d+\S* Kč*
#\d+&\w+;\d+&\w+;Kč* 
with open('regex_rules2.txt', 'w') as f:
    
    f.write(rules2)

# %%
RegexMatcher().extractParamMap()

documentAssembler2 = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("assembled")

regex_matcher2 = RegexMatcher()\
    .setInputCols('assembled')\
    .setStrategy("MATCH_ALL")\
    .setOutputCol("regex_address")\
    .setExternalRules(path='./regex_rules2.txt', delimiter=',')

nlpPipeline2 = Pipeline(stages=[
    documentAssembler2, 
    regex_matcher2
 ])

# %%
pipelineModel2 = nlpPipeline2.fit(df)

match_df2 = pipelineModel2.transform(df)

match_df2.select('regex_address.result').show(truncate=400)
# Out:
# +---------------------------------------------------------------+
# |                                                         result|
# +---------------------------------------------------------------+
# |   [location-text ng-binding">Masná, Praha 1 - Staré Město</sp]|
# |       [location-text ng-binding">Velvarská, Horoměřice</span>]|
# |      [location-text ng-binding">Libušina, Karlovy Vary</span>]|
# |    [location-text ng-binding">Pod Lipami, Praha 3 - Žižkov</s]|
# |  [location-text ng-binding">Drnovská, Praha 6 - Ruzyně</span>]|
# |      [location-text ng-binding">V Průhoně, Mukařov - Žernovka]|
# |    [location-text ng-binding">Mladoboleslavská, Mělník</span>]|
# | [location-text ng-binding">Grafická, Praha 5 - Smíchov</span>]|
# |[location-text ng-binding">Sametová, Liberec - Liberec VI-Roch]|
# |[location-text ng-binding">Jakubská, Praha 1 - Staré Město</sp]|
# +---------------------------------------------------------------+

# %%
from pyspark.sql import functions as F

match_df2.select(F.explode('regex_address.result')).show(truncate=False)
# Out:
# +-------------------------------------------------------------+
# |col                                                          |
# +-------------------------------------------------------------+
# |location-text ng-binding">Masná, Praha 1 - Staré Město</sp   |
# |location-text ng-binding">Velvarská, Horoměřice</span>       |
# |location-text ng-binding">Libušina, Karlovy Vary</span>      |
# |location-text ng-binding">Pod Lipami, Praha 3 - Žižkov</s    |
# |location-text ng-binding">Drnovská, Praha 6 - Ruzyně</span>  |
# |location-text ng-binding">V Průhoně, Mukařov - Žernovka      |
# |location-text ng-binding">Mladoboleslavská, Mělník</span>    |
# |location-text ng-binding">Grafická, Praha 5 - Smíchov</span> |
# |location-text ng-binding">Sametová, Liberec - Liberec VI-Roch|
# |location-text ng-binding">Jakubská, Praha 1 - Staré Město</sp|
# +-------------------------------------------------------------+

# %%
result_df2 = match_df2.select(F.explode('regex_address.result').alias('location-text ng-binding')).toPandas()
result_df2
# Out:
#                                         location-text ng-binding
# 0     location-text ng-binding">Masná, Praha 1 - Staré Město</sp
# 1         location-text ng-binding">Velvarská, Horoměřice</span>
# 2        location-text ng-binding">Libušina, Karlovy Vary</span>
# 3      location-text ng-binding">Pod Lipami, Praha 3 - Žižkov</s
# 4    location-text ng-binding">Drnovská, Praha 6 - Ruzyně</span>
# 5        location-text ng-binding">V Průhoně, Mukařov - Žernovka
# 6      location-text ng-binding">Mladoboleslavská, Mělník</span>
# 7   location-text ng-binding">Grafická, Praha 5 - Smíchov</span>
# 8  location-text ng-binding">Sametová, Liberec - Liberec VI-Roch
# 9  location-text ng-binding">Jakubská, Praha 1 - Staré Město</sp

# %%
rules3 = '''


<div\s\w*ss[^>]*(.+?)

'''
#<!--\s\w*eat.\s\w*[^</div](.+?)/\d
#(\<\w*div\s\w*lass\=\"\w*arams\s\w*lear\<)
#\<\w*div\s\w*lass\=\"\w*arams\s\w*lear..\n\<\!\-\-\s\w*eat\:
#\<\w*div\s\w*lass\=\"\w*arams\.*class="param-label ng-binding.*\n
#.*Eventname .*\n
#\<\w*div\s\w*lass\=\"\w*arams\s\w*lear..\n\<\!\-\-\s\w*eat
#\<\w*div\s\w*lass\=\"\w*arams\s\w*lear
#\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w*........................
#\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w*
#\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w*.........................
#/<title>([^<]+)<\/title>/
#\w*tion\-\w*ext\s+\w*ng\-\w*binding\"\>\w+|\s.$\<\/
#\S*\d+\S* Kč*
#\d+&\w+;\d+&\w+;Kč* 
with open('regex_rules3.txt', 'w') as f:
    
    f.write(rules3)

# %%
RegexMatcher().extractParamMap()

documentAssembler3 = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("assembled")

regex_matcher3 = RegexMatcher()\
    .setInputCols('assembled')\
    .setStrategy("MATCH_ALL")\
    .setOutputCol("regex_params")\
    .setExternalRules(path='./regex_rules3.txt', delimiter=',')

nlpPipeline3 = Pipeline(stages=[
    documentAssembler3, 
    regex_matcher3
 ])

# %%
#<div\s\w*[^>]*

# %%
pipelineModel3 = nlpPipeline3.fit(df)

match_df3 = pipelineModel3.transform(df)

match_df3.select('regex_params.result').show(truncate=80000)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scop ...
# |                                                                                                                                                                                                                                                                                                                                                                                              [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ show: isThumbnails(), 'fl-detail': isFullscreen() }" ng-click="showEntity(SHOW_ENTITY.DETAIL)">, <div class="thumbnails-middle">, <div class="thumbnails-inner">, <div class="list" ng-class="{ 'less-than-five': data.images.length < 5 }">, <div class="thumb-image ng-scope active" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, < ...
# |[<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ show: isThumbnails(), 'fl-detail': isFullscreen() }" ng-click="showEntity(SHOW_ENTITY.DETAIL)">, <div class="thumbnails-middle">, <div class="thumbnails-inner">, <div class="list" ng-class="{ 'less-than-five': data.images.length < 5 }">, <div class="thumb-image ng-scope active" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: sele ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ show: isThumbnails(), 'fl-detail': isFullscreen() }" ng-click="showEntity(SHOW_ENTITY.DETAIL)">, <div class="thumbnails-middle">, <div class="thumbnails-inner">, <div class="list" ng-class="{ 'less-than-five': data.images.length < 5 }">, <div class="thumb-image ng-scope active" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ show: isThumbnails(), 'fl-detail': isFullscreen() }" ng-click="showEntity(SHOW_ENTITY.DETAIL)">, <div class="thumbnails-middle">, <div class="thumbnails-inner">, <div class="list" ng-class="{ 'less-than-five': data.images.length < 5 }">, <div class="thumb-image ng-scope active" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class="{ active: selected.active == $index, loading: image.thumbLoad &amp;&amp; image.image}">, <div class="thumb-image ng-scope" ng-repeat="image in data.images track by $index" ng-click="openFullscreenPhoto($event, $index)" ng-class=" ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ show: isThumbnails(), 'fl-detail': isFullscreen() }" ng-click="showEntity(SHOW_ENTITY.DETAIL)">, <div class="thumbnails-middle">, <div class="thumbnails-inner">, <div class="list" ng-class="{ 'less-than-five': data.images.length <  ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ s ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-cl ...
# |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [<div class="loading-line" style="display: block; transform: translate(-100%, 0px); transition: none 0s ease 0s;">, <div class="content-cover">, <div class="anchor-wrap ng-isolate-scope" ng-if="!pageLayout.empty" gallery-anchor="">, <div class="page-header clear ng-isolate-scope" ng-if="!pageLayout.empty" header="">, <div class="app-promotion ng-isolate-scope ng-hide" data-ng-show="showed" data-ng-class="{'app-promotion-hiding': hiding}">, <div class="app-promotion-info">, <div class="app-promotion-name ng-binding">, <div class="app-promotion-author ng-binding">, <div class="app-promotion-rating">, <div class="app-promotion-price">, <div class="login-badge-wrapper">, <div class="property-detail ng-scope">, <div class="content ng-scope" ng-if="resource" ng-class="{'show-report-error': showErrorReport}">, <div class="navigation-detail">, <div class="crumb-back ng-isolate-scope" crumb-back="">, <div class="left">, <div class="iterator ng-isolate-scope" iterator="">, <div class="left">, <div class="right">, <div class="navigation-fixer rows-2">, <div class="hud">, <div class="noprint">, <div class="copyright print" title=" Seznam.cz, a.s., 2021 |  OpenStreetMap" style="position: absolute; inset: auto auto 3px 5px;">, <div class="gallery ng-isolate-scope" ng-class="{ 'old-browsers': oldBrowsers }" gallery="resource">, <div class="fullscreen-mode ng-hide" ng-show="!isDetail()">, <div class="background">, <div class="fl-images prev">, <div class="fl-images active" ng-class="{ loading: images.fullscreen.active.loading &amp;&amp; !images.fullscreen.panorama &amp;&amp; !images.fullscreen.sphere, 'panorama-fullscreen': images.fullscreen.panorama }" swipe="" swipe-right="prevPhoto()" swipe-left="nextPhoto()" ng-click="fullscreenClick(images.fullscreen)" style="touch-action: pan-y; user-select: none; -webkit-user-drag: none; -webkit-tap-highlight-color: rgba(0, 0, 0, 0);">, <div class="download-cover">, <div class="fl-images next">, <div class="thumbnails-outter" ng-class="{ show: isThumbnails(), 'fl-detail': isFullscreen() }" ng-click="showEntity(SHOW_ENTITY.DETAIL)">, <div class="thumbnails-middle">, <div class="thumbnails-inner">, <div class="list" ng-class="{ 'less-than-five': data.images.length < 5 }">, <div class="thumb-image ng-scope active" ng-repeat="image in data.images track by $index" ng-click="openFullscr ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %% [markdown]
# match_df.select('regex_matches.result')

# %%
match_df2.select('regex_address.result').show(truncate=False)
# Out:
# +------------------------------------------------------------+
# |result                                                      |
# +------------------------------------------------------------+
# |[location-text ng-binding">Masná, Praha 1 - Staré Město<]   |
# |[location-text ng-binding">Velvarská, Horoměřice</span>]    |
# |[location-text ng-binding">Libušina, Karlovy Vary</span>]   |
# |[location-text ng-binding">Pod Lipami, Praha 3 - Žižkov]    |
# |[location-text ng-binding">Drnovská, Praha 6 - Ruzyně</span]|
# |[location-text ng-binding">V Průhoně, Mukařov - Žerno]      |
# |[location-text ng-binding">Mladoboleslavská, Mělník</span>] |
# |[location-text ng-binding">Grafická, Praha 5 - Smíchov</spa]|
# |[location-text ng-binding">Sametová, Liberec - Liberec VI-R]|
# |[location-text ng-binding">Jakubská, Praha 1 - Staré Město<]|
# +------------------------------------------------------------+

# %%
rdd_df_join = match_df.select('regex_matches.result').join(match_df2.select('regex_address.result'))

# %%
match_df_pd_cost = match_df.select('regex_matches.result').toPandas()
match_df_pd_address = match_df2.select('regex_address.result').toPandas()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-416-40d5c66913d1> in <module>
#       1 match_df_pd_cost = match_df.select('regex_matches.result').toPandas()
# ----> 2 match_df_pd_address = match_df2.select('regex_address.result').toPandas()
#
# AttributeError: 'PipelinedRDD' object has no attribute 'select'

# %%
match_df_pd
# Out:
#                    result
# 0  [500&nbsp;000&nbsp;Kč]
# 1  [200&nbsp;000&nbsp;Kč]
# 2  [854&nbsp;900&nbsp;Kč]
# 3  [565&nbsp;000&nbsp;Kč]
# 4  [475&nbsp;000&nbsp;Kč]
# 5  [500&nbsp;000&nbsp;Kč]
# 6  [530&nbsp;000&nbsp;Kč]
# 7  [511&nbsp;000&nbsp;Kč]
# 8  [850&nbsp;000&nbsp;Kč]
# 9  [490&nbsp;000&nbsp;Kč]

# %%
pd.set_option('display.max_colwidth', None)

# %%
import pandas as pd

# %%
df_concat_cost_address = pd.concat([match_df_pd_cost,match_df_pd_address], axis=1)

# %%
df_concat_cost_address
# Out:
#                    result  \
# 0  [500&nbsp;000&nbsp;Kč]
# 1  [200&nbsp;000&nbsp;Kč]
# 2  [854&nbsp;900&nbsp;Kč]
# 3  [565&nbsp;000&nbsp;Kč]
# 4  [475&nbsp;000&nbsp;Kč]
# 5  [500&nbsp;000&nbsp;Kč]
# 6  [530&nbsp;000&nbsp;Kč]
# 7  [511&nbsp;000&nbsp;Kč]
# 8  [850&nbsp;000&nbsp;Kč]
# 9  [490&nbsp;000&nbsp;Kč]
#
#                                                          result
# 0     [location-text ng-binding">Masná, Praha 1 - Staré Město<]
# 1      [location-text ng-binding">Velvarská, Horoměřice</span>]
# 2     [location-text ng-binding">Libušina, Karlovy Vary</span>]
# 3      [location-text ng-binding">Pod Lipami, Praha 3 - Žižkov]
# 4  [location-text ng-binding">Drnovská, Praha 6 - Ruzyně</span]
# 5        [location-text ng-binding">V Průhoně, Mukařov - Žerno]
# 6   [location-text ng-binding">Mladoboleslavská, Mělník</span>]
# 7  [location-text ng-binding">Grafická, Praha 5 - Smíchov</spa]
# 8  [location-text ng-binding">Sametová, Liberec - Liberec VI-R]
# 9  [location-text ng-binding">Jakubská, Praha 1 - Staré Město<]

# %%
rdd_temp =match_df.zip(match_df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-385-7faa418062f3> in <module>
# ----> 1 rdd_temp =match_df.zip(match_df2)
#
# ~/.local/lib/python3.6/site-packages/pyspark/sql/dataframe.py in __getattr__(self, name)
#    1658         if name not in self.columns:
#    1659             raise AttributeError(
# -> 1660                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1661         jc = self._jdf.apply(name)
#    1662         return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'zip'
