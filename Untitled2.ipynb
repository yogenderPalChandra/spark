# %%
import requests
page = requests.get("https://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>]

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.NavigableString, bs4.element.Tag]

# %%
html = list(soup.children)[2]

# %%
html
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>A simple example page</title>
#  </head>,
#  '\n',
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>,
#  '\n']

# %%
body = list(html.children)[3]

# %%
body
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %%
list(body.children)
# Out:
# ['\n', <p>Here is some simple content for this page.</p>, '\n']

# %%
p = list(body.children)[1]

# %%
p
# Out:
# <p>Here is some simple content for this page.</p>

# %%
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p>Here is some simple content for this page.</p>]

# %%
soup.find_all('p')[0].get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
page = requests.get("https://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>
# <p class="inner-text">
#                 Second paragraph.
#             </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 First outer paragraph.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 Second outer paragraph.
#             </b>
# </p>
# </body>
# </html>

# %%
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %%
soup.find_all(class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %%
soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>]

# %%
soup.select("div p")
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>,
#  <p class="inner-text">
#                  Second paragraph.
#              </p>]

# %%
page = requests.get("https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
#soup
seven_day = soup.find(id="seven-day-forecast")
#seven_day
forecast_items = seven_day.find_all(class_="tombstone-container")
#forecast_items
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Overnight
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Overnight: Cloudy, with a low around 50. Southwest wind around 7 mph. " class="forecast-icon" src="newimages/medium/novc.png" title="Overnight: Cloudy, with a low around 50. Southwest wind around 7 mph. "/>
#  </p>
#  <p class="short-desc">
#   Cloudy
#  </p>
#  <p class="temp temp-low">
#   Low: 50 °F
#  </p>
# </div>

# %%
period = tonight.find(class_="period-name").get_text()
short_desc = tonight.find(class_="short-desc").get_text()
temp = tonight.find(class_="temp").get_text()
print(period)
print(short_desc)
print(temp)
# Out:
# Overnight
# Cloudy
# Low: 50 °F

# %%
sc = SparkContext(conf=conf)

spark = SparkSession(sc)
movies = sc.textFile("file:///home/ajit/ml-25m/movies.csv")

#or using spark.sparkContext
movies = spark.sparkContext.textFile("file:///home/ajit/ml-25m/movies.csv")

parsedLines = movies.map(parsedLine)
print(parsedLines.count())

dataFrame = parsedLines.toDF(["movieId"])
dataFrame.printSchema()

# %%
from time import time

from bs4 import BeautifulSoup
from urllib.request import urlopen
from pyspark import SparkContext
from pyspark.sql import SparkSession

#spark = SparkSession.builder.getOrCreate()
sc = SparkContext()
spark = SparkSession(sc)
#sc.stop()
# Out:
# /home/yogender/.local/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning

# %%
from pyspark.sql.functions import udf
from simplified_scrapy.simplified_doc import SimplifiedDoc 

#define and register udf

def text_simple_udf(text_in): 
    return SimplifiedDoc(text_in).text

# %%
import os
cwd=os.getcwd()
html = '69468.html'
path = os.path.join(os.getcwd(), html)
path
#fileInContext = sc.textFile(path)
#fileD = spark.sparkContext.textFile(path)
#rdd = sc.textFile(path)
fileInContext
data = spark.read.text(path)
rows = data.collect()[6]
rows
sc.stop()

# %%
tst = text_simple_udf(rows)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b8c2f84d92e4> in <module>
# ----> 1 tst = text_simple_udf(rows)
#
# <ipython-input-6-bc974730284a> in text_simple_udf(text_in)
#       5
#       6 def text_simple_udf(text_in):
# ----> 7     return SimplifiedDoc(text_in).text
#
# ~/.local/lib/python3.6/site-packages/simplified_scrapy/simplified_doc.py in __init__(self, html, start, end, before, edit, preDeal)
#      29             sec = getSection(html, start, end, before)
#      30             if (sec): html = html[sec[0]:sec[1]]
# ---> 31             html = preDealHtml(html)
#      32         if html:
#      33             self['html'] = html
#
# ~/.local/lib/python3.6/site-packages/simplified_scrapy/core/regex_helper.py in preDealHtml(html)
#     222
#     223 def preDealHtml(html):
# --> 224     html = __re0.sub(_replaceHtml, html)  # script?
# ...

# %%
def soupify(path):
    with open(path) as fp:
        soup = BeautifulSoup(fp, "html.parser")
        soup
        #print(soup.prettify())
        return soup
    #data = spark.sparkContext.wholeTextFiles(fpath)
    #data = spark.read.text(fpath)

# %%
temp = fileD.map(soupify(path)).collect()
#schemaPeople = sc.createDataFrame(temp)
temp.limit(50)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle/cloudpickle_fast.py in dump(self, obj)
#     562         try:
# --> 563             return Pickler.dump(self, obj)
#     564         except RuntimeError as e:
#
# /usr/lib/python3.6/pickle.py in dump(self, obj)
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_tuple(self, obj)
#     750         for element in obj:
# --> 751             save(element)
#     752
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
# ...

# %%
import sys
sys.setrecursionlimit(3000)
temp.toDF()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pyspark/cloudpickle/cloudpickle_fast.py in dump(self, obj)
#     562         try:
# --> 563             return Pickler.dump(self, obj)
#     564         except RuntimeError as e:
#
# /usr/lib/python3.6/pickle.py in dump(self, obj)
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/lib/python3.6/pickle.py in save_tuple(self, obj)
#     750         for element in obj:
# --> 751             save(element)
#     752
#
# /usr/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-c5ee73d90b6d> in <module>
# ----> 1 temp_rdd = temp.show()
#
# AttributeError: 'PipelinedRDD' object has no attribute 'show'

# %%
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-27-5779fff2a616> in <module>
# ----> 1 for elem in temp.collect():
#       2     print(elem)
#
# ~/miniconda3/envs/pyspark/lib/python3.9/site-packages/pyspark/rdd.py in collect(self)
#     947         """
#     948         with SCCallSiteSync(self.context) as css:
# --> 949             sock_info = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     950         return list(_load_from_socket(sock_info, self._jrdd_deserializer))
#     951
#
# ~/miniconda3/envs/pyspark/lib/python3.9/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ...
